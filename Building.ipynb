# %%
import csv
with open('laptop.csv') as f:
    book = csv.read(f)
    header = book[0]
    rows = book[1:]
header
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6552fb3b41b8> in <module>
#       1 import csv
# ----> 2 with open('laptop.csv') as f:
#       3     book = csv.read(f)
#       4     header = book[0]
#       5     rows = book[1:]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'laptop.csv'

# %%
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 0000-4823
#
#  Directory of c:\Users\Nam Hung\Documents\GitHub\Building-Fast-Queries-on-a-CSV
#
# 14/07/2021  09:42 CH    <DIR>          .
# 14/07/2021  09:42 CH    <DIR>          ..
# 14/07/2021  09:38 CH                66 .gitattributes
# 14/07/2021  09:44 CH             2.604 Building.ipynb
# 01/01/1970  07:00 SA           197.908 laptops.csv
#                3 File(s)        200.578 bytes
#                2 Dir(s)  22.870.315.008 bytes free
